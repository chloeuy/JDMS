# %%
# %%time 
import numpy as np 
import pandas as pd 
import scipy
import matplotlib
import matplotlib.pyplot as plt

from sklearn.cluster import DBSCAN 
from sklearn.preprocessing import StandardScaler 
from sklearn.neighbors import NearestNeighbors
from sklearn.preprocessing import normalize 
from sklearn.decomposition import PCA 
from sklearn import metrics 
from sklearn.metrics import silhouette_score, homogeneity_completeness_v_measure
from sklearn.metrics.pairwise import euclidean_distances
from hdbscan import HDBSCAN
from scipy.stats import spearmanr 

import warnings 
warnings.simplefilter("ignore") 


from scipy.spatial.distance import pdist
# Out:
# CPU times: user 74 µs, sys: 7 µs, total: 81 µs
# Wall time: 90.8 µs

# %%
df = pd.read_pickle('picklefinal/trans_famd.pkl')

# %%
df.head()
# Out:
#                                             0            1            2  \
# UniqueID
# 00000f7264c27ba6fea0c837ed6aa0aa  2777.831280 -1089.606573  1083.391346
# 00001e984eba85527fd3122056451279  3467.555696  -777.902490 -1839.019797
# 0000219e4b37d2504fb6b8c28e24a2d4  2964.429453  1753.002911   583.171283
# 000026c67a83fa72aec14512887bb173  2865.255748 -1193.791027  1436.266510
# 000028899fe7782862d40bb1b87807ee  3061.093631  -485.905438   -27.082927
#
#                                             3            4            5  \
# UniqueID
# 00000f7264c27ba6fea0c837ed6aa0aa  2601.628903 -1056.322349 -1565.667062
# 00001e984eba85527fd3122056451279   -15.492069    19.577773  -315.410871
# 0000219e4b37d2504fb6b8c28e24a2d4   142.977934 -2894.996956  -196.526472
# 000026c67a83fa72aec14512887bb173 -1709.640234   213.803533 -1401.276478
# 000028899fe7782862d40bb1b87807ee   787.831721  3104.735730  -854.543511
#
#                                             6            7            8  \
# UniqueID
# 00000f7264c27ba6fea0c837ed6aa0aa   337.820770   842.202369   186.990991
# 00001e984eba85527fd3122056451279   -99.143818   849.925131  1050.015535
# 0000219e4b37d2504fb6b8c28e24a2d4 -1418.313731   498.537934   100.195773
# 000026c67a83fa72aec14512887bb173  1154.285689  1287.179009  -262.357848
# 000028899fe7782862d40bb1b87807ee  -301.011424  -390.369093 -1758.861716
#
#                                             9
# UniqueID
# 00000f7264c27ba6fea0c837ed6aa0aa  -504.224420
# 00001e984eba85527fd3122056451279 -1779.120183
# 0000219e4b37d2504fb6b8c28e24a2d4  -309.322824
# 000026c67a83fa72aec14512887bb173 -2096.064227
# 000028899fe7782862d40bb1b87807ee   315.609065

# %%
#convert to array 
ar = df.to_numpy()

# %%
from pyclustering.cluster import cluster_visualizer;
from pyclustering.cluster.cure import cure;
from pyclustering.utils import read_sample;
from pyclustering.samples.definitions import FCPS_SAMPLES;

# %%
# Allocate ten clusters.
cure_instance = cure(ar, 10);
cure_instance.process();
clusters = cure_instance.get_clusters();
